# %% [markdown]
# <a href="https://colab.research.google.com/github/dhelawatad/ML/blob/master/computervision.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import cv2
import matplotlib.pyplot as plt
from google.colab.patches import cv2_imshow

# %%
cv2.__version__
# Out:
# '3.4.3'

# %%
img=cv2.imread('download.jpg')
img1=cv2.imread('download.jpg',2)

# %%
img
# Out:
# array([[[ 62,  58,  87],
#         [ 81,  79, 109],
#         [ 98,  95, 134],
#         ...,
#         [ 80, 167, 139],
#         [ 82, 170, 140],
#         [ 81, 169, 139]],
#
#        [[ 59,  53,  84],
#         [ 65,  59,  94],
#         [ 71,  65, 106],
#         ...,
#         [ 67, 159, 130],
#         [ 65, 158, 127],
#         [ 67, 161, 130]],
#
#        [[ 69,  58,  96],
#         [ 62,  53,  93],
#         [ 54,  44,  90],
#         ...,
#         [ 54, 150, 120],
#         [ 44, 145, 113],
#         [ 42, 149, 116]],
#
#        ...,
#
#        [[129, 138, 181],
#         [ 94, 103, 146],
#         [ 59,  66, 109],
#         ...,
#         [  5,  95,  65],
#         [  3,  98,  64],
#         [ 13, 106,  75]],
#
#        [[132, 141, 179],
#         [ 87,  96, 134],
#         [ 42,  47,  86],
#         ...,
#         [  8,  95,  69],
#         [  4,  97,  66],
#         [ 14, 106,  77]],
#
#        [[ 81,  86, 117],
#         [ 65,  68,  99],
#         [ 55,  54,  86],
# ...

# %%
print(img.shape)
# Out:
# (225, 225, 3)

# %%
type((img))
# Out:
# numpy.ndarray

# %%
plt.imshow(img)

# %%
plt.imshow(img1)
